# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavchandel13/Pandas/blob/main/PracticeDATaSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing required library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# importing dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/LungCap.csv')
df
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 0          6.475            6            62.1    no    male        no
# 1         10.125           18            74.7   yes  female        no
# 2          9.550           16            69.7    no  female       yes
# 3         11.125           14            71.0    no    male        no
# 4          4.800            5            56.9    no    male        no
# ..           ...          ...             ...   ...     ...       ...
# 720        5.725            9            56.0    no  female        no
# 721        9.050           18            72.0   yes    male       yes
# 722        3.850           11            60.5   yes  female        no
# 723        9.825           15            64.9    no  female        no
# 724        7.100           10            67.7    no    male        no
#
# [725 rows x 6 columns]

# %% [markdown]
# Check the last 5 rows of the dataset

# %%
df.tail()
# Out:
#      LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 720        5.725            9            56.0    no  female        no
# 721        9.050           18            72.0   yes    male       yes
# 722        3.850           11            60.5   yes  female        no
# 723        9.825           15            64.9    no  female        no
# 724        7.100           10            67.7    no    male        no

# %% [markdown]
# # Display rows in range of 5 to 10

# %%
df[5:11]
# Out:
#     LungCap(cc)  Age( years)  Height(inches) Smoke  Gender Caesarean
# 5         6.225           11            58.7    no  female        no
# 6         4.950            8            63.3    no    male       yes
# 7         7.325           11            70.4    no    male        no
# 8         8.875           15            70.5    no    male        no
# 9         6.800           11            59.2    no    male        no
# 10       11.500           19            76.4    no    male       yes

# %% [markdown]
# # Check the information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725 entries, 0 to 724
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LungCap(cc)     725 non-null    float64
#  1   Age( years)     725 non-null    int64
#  2   Height(inches)  725 non-null    float64
#  3   Smoke           725 non-null    object
#  4   Gender          725 non-null    object
#  5   Caesarean       725 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 34.1+ KB
